# %%
import re
import srt
import string
import wordcloud
import nltk
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from wordcloud import WordCloud
from collections import Counter


def open_srt(srt_file):
    """
    Return a list of string
    """
    generator = srt.parse(srt_file.read())
    return [g for g in generator]

def tokenize_subtittle(subtittle):
    excluded_chars = str.maketrans('', '', string.punctuation + "¡¿\1234567890")
    words = subtittle.content.translate(excluded_chars).strip().lower().replace('\n', ' ')
    words = re.sub(' +', ' ', words)
    return words
    
def create_wordclod(string, stop_words, filename):
   cloud = WordCloud(background_color="white", max_words=200, stopwords=set(stop_words), width=800, height=600)
   cloud.generate(string)
   cloud.to_file(filename)

def get_most_common_words(words, n=10):
   wordcount = Counter([w for w in words.split(' ') if len(w) > 1])
   ranking = {k: v for k, v in sorted(wordcount.items(), key=lambda item: item[1])}
   return list(ranking.keys())[-n:]

# %%
with open("Parasite.srt", encoding="ISO-8859-1") as srt_file:
    subtittles = open_srt(srt_file)

# %%
words = ' '.join(map(tokenize_subtittle, subtittles))

# %%
stop_words = stopwords.words('spanish') + get_most_common_words(words)

# %%
words
# Out:
# 'e acabó no más wifi gratis oye kijung í la señora de arriba puso una contraseña a su wifi una contraseña intentaste con 123 no funciona hazlo al revés ya lo intenté mierda entonces no podemos usar whatsapp nada oye jim kitaek no finjas que estás durmiendo qué opinas nuestros teléfonos no funcionan ahora nuestro wifi está cortado cuál es tu plan kiwoo í papá busca una señal wifi levanta la mano busca en cada esquina y así sucesivamente malditos insectos apestosos por aquí lo tengo en serio tienes señal í lo ves éstacoffeeland 2g han abierto una nueva cafetería por qué no puedo conectarme ube hasta aquí oigan chicos funciona í revisa el whatsapp dijeron que pizza generation se pondría en contacto conmigo espera aquí está pizza generation miren esto chicos i lo hacemos tan rápido como ella podemos terminarlo para hoy entonces nos pagarán nos pondremos de pie también ella es una profesional qué fumigación todavía hacen ese tipo de cosas upongo que sí cierra la ventana déjala abierta tendremos fumigación gratis matará a los insectos apestosos cierto hay muchos insectos apestosos en estos días dios eso apesta te dije que la cerraras debería cerrarla papá cuál es el problema tomemos este como ejemplo llamas a esto una línea recta y por qué está doblado aquí por qué está suelto esto ni siquiera lo doblaste una cuarta parte de ellos se ven así así que 1 de cada serán descartados entonces realmente estás descontando el 1 de nuestra paga considerando los rechazos es un costo muy bajo no nuestra paga ya es muy baja cómo puedes hacernos esto mire no se trata de una cuestión menor abes qué puede hacer un caja de mierda con nuestra imagen de marca marca ni siquiera puedes costear una caja plegadora qué has dicho jefa todo esto es por ese chico verdad qué chico u empleado a tiempo parcial e ha ido sin permiso verdad justo cuando la iglesia del amor de dios hizo un gran pedido grupal cómo sabes todo eso quién te lo dijo mi hermana conoce al chico iempre ha sido un poco extraño tiene mala reputación hablando de eso jefa aceptaremos una multa del 1 a cambio de eso a cambio de eso ha pensado en contratar a un nuevo trabajador a tiempo parcial hermana necesitamos a alguien deshazte del chico que tienes ahora ólo despídelo mañana iré para una entrevista formal a qué hora espera espera un segundo déjame pensarlo entonces por ahora sólo páguenos por las cajas así que estamos todos reunidos aquí hoy para celebrar la reconexión de nuestros teléfonos y este generoso wifi mira a ese bastardo ni siquiera ha oscurecido aún por qué no pusiste un letrero de no orinar te lo dije no letreros como esos sólo hacen que orinen aún más al menos grítale no grites por favor no orines oye ese es min oiga señor eso no es un baño bien hecho min oye idiota a quién miras imbécil ven aquí pequeña mierda contrólate carajo es un amigo impresionante los estudiantes universitarios tienen un gran vigor no como mi hermano pero vendrá aquí lo invitaste no hola hola min min e encuentra bien señor claro qué estás haciendo aquí te envié un mensaje de texto no lo has visto lo siento estaban comiendo no no estábamos comiendo cómo estás kijung bien y tú podríamos habernos encontrado en otro lugar por qué has venido aquí debido a esto es para ti pero es muy pesado en serio ponlo aquí vaya qué es eso cuando dije que iba a ver a kiwoo mi abuelo insistió en que te trajera esto es algo decorativo o puedes verlo como algo abstracto vaya sabe de esto mi abuelo ha coleccionado rocas de erudito desde sus días de cadete ahora el anexo el estudio cada habitación de la casa está llena de estas cosas pero se dice que esta roca trae riqueza material a las familias min esto es tan metafórico por supuesto es un regalo muy oportuno por supuesto por favor dale nuestro más profundo agradecimiento a su abuelo algo de comida sería mejor cómo se llamaba esa cosa una roca decorativa también coleccionas esas rocas oye gracias a esa roca vi a tus padres se ven saludables están muy sanos sin trabajo kijung est ...

# %%
stop_words
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened',
#  'por',
#  'qué',
#  'un',
#  'el',
#  'en',
#  'no',
#  'que',
#  'es',
#  'la',
#  'de']

# %%
create_wordclod(words, stop_words, "parasite.png")
